# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# αの減衰具合についてグラフにする

initial_alpha1 = 1
initial_alpha2 = 10
iteraion_num = 10**6
iteration_list = []
alpha_list1 = []
alpha_list2 = []
check_point_list = [int(j) for j in np.logspace(0, len(str(iteraion_num)), (len(str(iteraion_num)))*4 , endpoint=False)]
for i in range(1, iteraion_num+1):
  if i in check_point_list :
    alpha1 = initial_alpha1/(i**0.5)
    alpha_list1.append(alpha1)
    alpha2 = initial_alpha/(i**0.5)
    alpha_list2.append(alpha2)


    iteration_list.append(i)

# %%
plt.figure(figsize=(10,6))
plt.plot(iteration_list, alpha_list1, label="initial_alpha:{}".format(initial_alpha1))
plt.plot(iteration_list, alpha_list2, label="initial_alpha:{}".format(initial_alpha2))
plt.xscale('log')
plt.xlabel('iteration')
plt.ylabel('alpha')
plt.legend()
plt.grid()
#plt.savefig("./png/alpha.png")
